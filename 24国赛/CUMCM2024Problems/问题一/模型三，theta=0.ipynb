# %% [markdown]
# # 耕地数据

# %%
import pandas as pd 
area_class=pd.read_excel(r"D:\adocument\数学建模\24年国赛\CUMCM2024Problems\附件1.xlsx")
area_class=area_class.drop(columns=['说明 '])
area_class.rename(columns={'地块名称': '种植地块'}, inplace=True)
area_class
# Out:
#    种植地块  地块类型  地块面积/亩
# 0    A1   平旱地    80.0
# 1    A2   平旱地    55.0
# 2    A3   平旱地    35.0
# 3    A4   平旱地    72.0
# 4    A5   平旱地    68.0
# 5    A6   平旱地    55.0
# 6    B1    梯田    60.0
# 7    B2    梯田    46.0
# 8    B3    梯田    40.0
# 9    B4    梯田    28.0
# 10   B5    梯田    25.0
# 11   B6    梯田    86.0
# 12   B7    梯田    55.0
# 13   B8    梯田    44.0
# 14   B9    梯田    50.0
# 15  B10    梯田    25.0
# 16  B11    梯田    60.0
# 17  B12    梯田    45.0
# 18  B13    梯田    35.0
# 19  B14    梯田    20.0
# 20   C1   山坡地    15.0
# 21   C2   山坡地    13.0
# 22   C3   山坡地    15.0
# 23   C4   山坡地    18.0
# 24   C5   山坡地    27.0
# 25   C6   山坡地    20.0
# 26   D1   水浇地    15.0
# 27   D2   水浇地    10.0
# 28   D3   水浇地    14.0
# 29   D4   水浇地     6.0
# 30   D5   水浇地    10.0
# 31   D6   水浇地    12.0
# 32   D7   水浇地    22.0
# 33   D8   水浇地    20.0
# 34   E1  普通大棚     0.6
# 35   E2  普通大棚     0.6
# 36   E3  普通大棚     0.6
# 37   E4  普通大棚     0.6
# 38   E5  普通大棚     0.6
# 39   E6  普通大棚     0.6
# 40   E7  普通大棚     0.6
# 41   E8  普通大棚     0.6
# 42   E9  普通大棚     0.6
# 43  E10  普通大棚     0.6
# 44  E11  普通大棚     0.6
# 45  E12  普通大棚     0.6
# 46  E13  普通大棚     0.6
# 47  E14  普通大棚     0.6
# 48  E15  普通大棚     0.6
# 49  E16  普通大棚     0.6
# 50   F1  智慧大棚     0.6
# 51   F2  智慧大棚     0.6
# 52   F3  智慧大棚     0.6
# 53   F4  智慧大棚     0.6

# %%
import pandas as pd
from openpyxl import load_workbook

data2=pd.read_excel(r"D:\adocument\数学建模\24年国赛\CUMCM2024Problems\附件2.xlsx",sheet_name=0)
data2 = data2.fillna(method='ffill')

crop=data2[['种植地块','作物编号','作物名称','作物类型']]
type_mapping = {'A': '平旱地', 'B': '梯田', 'C': '山坡地', 'D': '水浇地', 'E': '普通大棚', 'F': '智慧大棚'}
data2['地块类型'] = data2['种植地块'].apply(lambda x: type_mapping[x[0]])
crop['是否豆类'] = crop['作物类型'].apply(lambda x: 1 if '豆类' in x else 0)
# # crop= crop.drop_duplicates(subset=['作物编号'], keep='first').reset_index()
# # crop=crop.drop(columns=['index'])
# crop_area=pd.merge(crop,area_class,on='种植地块')
# cerear=crop_area[crop_area['作物类型'].str.contains('粮食')][['作物编号', '作物名称', '作物类型','地块类型']]
# # cerear.set_index('作物编号', inplace=True)
# cerear = cerear.drop_duplicates(subset=['作物编号'], keep='first').reset_index()
# cerear=cerear.drop(columns=['index'])
# cerear=cerear[cerear['作物名称']!='水稻']
# cerear
crop_class=pd.read_excel(r"D:\adocument\数学建模\24年国赛\CUMCM2024Problems\附件1.xlsx",sheet_name=1)
crop_class=crop_class.drop(columns=['说明','种植耕地'])

crop_class['是否豆类'] = crop_class['作物类型'].apply(lambda x: 1 if '豆类' in x else 0)
crop_class
# Out:
# C:\Users\34999\AppData\Local\Temp\ipykernel_46596\1746026932.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data2 = data2.fillna(method='ffill')
# C:\Users\34999\AppData\Local\Temp\ipykernel_46596\1746026932.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crop['是否豆类'] = crop['作物类型'].apply(lambda x: 1 if '豆类' in x else 0)
#     作物编号 作物名称    作物类型  是否豆类
# 0      1   黄豆  粮食（豆类）     1
# 1      2   黑豆  粮食（豆类）     1
# 2      3   红豆  粮食（豆类）     1
# 3      4   绿豆  粮食（豆类）     1
# 4      5   爬豆  粮食（豆类）     1
# 5      6   小麦      粮食     0
# 6      7   玉米      粮食     0
# 7      8   谷子      粮食     0
# 8      9   高粱      粮食     0
# 9     10   黍子      粮食     0
# 10    11   荞麦      粮食     0
# 11    12   南瓜      粮食     0
# 12    13   红薯      粮食     0
# 13    14   莜麦      粮食     0
# 14    15   大麦      粮食     0
# 15    16   水稻      粮食     0
# 16    17   豇豆  蔬菜（豆类）     1
# 17    18   刀豆  蔬菜（豆类）     1
# 18    19   芸豆  蔬菜（豆类）     1
# 19    20   土豆      蔬菜     0
# 20    21  西红柿      蔬菜     0
# 21    22   茄子      蔬菜     0
# 22    23  菠菜       蔬菜     0
# 23    24   青椒      蔬菜     0
# 24    25   菜花      蔬菜     0
# 25    26   包菜      蔬菜     0
# 26    27  油麦菜      蔬菜     0
# 27    28  小青菜      蔬菜     0
# 28    29   黄瓜      蔬菜     0
# 29    30  生菜       蔬菜     0
# 30    31   辣椒      蔬菜     0
# 31    32  空心菜      蔬菜     0
# 32    33  黄心菜      蔬菜     0
# 33    34   芹菜      蔬菜     0
# 34    35  大白菜      蔬菜     0
# 35    36  白萝卜      蔬菜     0
# 36    37  红萝卜      蔬菜     0
# 37    38  榆黄菇     食用菌     0
# 38    39   香菇     食用菌     0
# 39    40  白灵菇     食用菌     0
# 40    41  羊肚菌     食用菌     0

# %%
market=pd.read_excel(r"D:\adocument\数学建模\24年国赛\CUMCM2024Problems\附件2.xlsx",sheet_name=1,index_col=0)
# market_cerear=pd.merge(m`arket,cerear,on=['作物编号','地块类型','作物名称'])
# cerear
# market_cerear.set_index('作物编号', inplace=True)
# market_cerear.sort_index()
muchan=market[['作物编号','地块类型','亩产量/斤']]
market
crop1=data2[data2['地块类型'].isin(['水浇地','普通大棚','智慧大棚'])]
x0=crop1[['种植地块','作物编号','种植面积/亩']].pivot_table(index='种植地块', columns='作物编号', values='种植面积/亩', aggfunc='sum', fill_value=0)
y0=x0.copy()
y0[y0>0]=int(1) 
x0.shape
# Out:
# (28, 26)

# %%
one_area=area_class[area_class['地块类型'].isin(['水浇地','普通大棚'])]
# one_area.set_index('种植地块',inplace=True)
# 创建一个作物编号列的表，将作物编号作为列名
one_muchan=muchan[muchan['地块类型'].isin(['水浇地','普通大棚'])].pivot_table(index='地块类型', columns='作物编号', values='亩产量/斤').reset_index()
pro= pd.merge(one_area['地块类型'],one_muchan, on='地块类型', how='left').drop(columns=['地块类型'])
muchan=market[market['地块类型'].isin(['水浇地', '普通大棚'])]
result = muchan[['作物编号', '地块类型', '种植成本/(元/亩)']].drop_duplicates().reset_index()
result=result.drop(columns=['序号'])
merged_data = pd.merge(one_area, result, on='地块类型')
pivot_data = merged_data.pivot_table(index='种植地块', columns='作物编号', values='种植成本/(元/亩)', aggfunc='first').reset_index()
bc=pivot_data.fillna(0).drop(columns='种植地块')
bc.shape
# Out:
# (24, 26)

# %%
import numpy as np
one_area=area_class[area_class['地块类型'].isin(['水浇地','普通大棚','智能大棚'])]
# one_area.set_index('种植地块',inplace=True)
# 创建一个作物编号列的表，将作物编号作为列名
one_muchan = market[market['地块类型'].isin(['水浇地', '普通大棚'])].pivot_table(index=['地块类型','种植季次'], columns='作物编号', values='亩产量/斤').reset_index()
pro= pd.merge(one_area['地块类型'],one_muchan, on='地块类型', how='left')
pro=pro.fillna(0)
pro1={}
# pro1[0]=pro[pro['种植季次']=='第一季'].drop(columns=['地块类型','种植季次'])
pro1[1]=pro[pro['种植季次']=='第二季'].drop(columns=['地块类型','种植季次'])
pro=pro[pro['种植季次']=='第二季'].drop(columns=['地块类型','种植季次'])
pro.iloc[0,0]
area=one_area['地块面积/亩']
area_=pd.read_excel(r"D:\adocument\数学建模\24年国赛\CUMCM2024Problems\area.xlsx",header=None, index_col=None)
area_=area_.to_numpy()
area= np.tile(area, (7, 1)).T
area=area-area_
area=area.T
area
# Out:
# array([[ 6.8175, 10.    ,  5.6   ,  6.    ,  4.6875,  0.    , 22.    ,
#         20.    ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,
#          0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,
#          0.6   ,  0.6   ,  0.6   ],
#        [15.    , 10.    , 14.    ,  6.    , 10.    , 12.    , 22.    ,
#         20.    ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,
#          0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,
#          0.6   ,  0.6   ,  0.6   ],
#        [15.    ,  4.    ,  0.    ,  6.    , 10.    , 12.    , 22.    ,
#         20.    ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,
#          0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,
#          0.6   ,  0.6   ,  0.6   ],
#        [ 6.4175, 10.    , 14.    ,  6.    , 10.    ,  0.    , 11.392 ,
#         20.    ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,
#          0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,
#          0.6   ,  0.6   ,  0.6   ],
#        [15.    , 10.    , 14.    ,  6.    , 10.    , 12.    , 22.    ,
#         20.    ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,
#          0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,
#          0.6   ,  0.6   ,  0.6   ],
#        [ 6.175 ,  4.    , 14.    ,  6.    , 10.    , 12.    , 13.2   ,
#         20.    ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,
#          0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,
#          0.6   ,  0.6   ,  0.6   ],
#        [15.    , 10.    ,  7.0875,  0.    ,  0.    ,  7.175 , 22.    ,
#         12.    ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,
#          0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,  0.6   ,
#          0.6   ,  0.6   ,  0.6   ]])

# %%
import numpy as np
plant_data = pd.read_excel(r"D:\adocument\数学建模\24年国赛\CUMCM2024Problems\附件2.xlsx",sheet_name="2023年的农作物种植情况")
plant_data['种植地块'] = plant_data['种植地块'].fillna(method='ffill')
plant_data
Statistics_data = pd.read_excel(r"D:\adocument\数学建模\24年国赛\CUMCM2024Problems\附件2z.xlsx",sheet_name="2023年统计的相关数据")
Statistics_data = Statistics_data.iloc[:107]
Statistics_data
# 将plant_data中的地块编号的第一个字符映射到Statistics_data的地块类型
type_mapping = {'A': '平旱地', 'B': '梯田', 'C': '山坡地', 'D': '水浇地', 'E': '普通大棚', 'F': '智慧大棚'}
plant_data['地块类型'] = plant_data['种植地块'].apply(lambda x: type_mapping[x[0]])

# 找到对应的行，并计算产量
merged_data = pd.merge(plant_data, Statistics_data, on=['地块类型', '作物编号'])
merged_data['总产量'] = merged_data['种植面积/亩'] * merged_data['亩产量/斤']

merged_data[['种植地块', '种植面积/亩', '作物编号', '地块类型', '亩产量/斤', '总产量']]
first_season_data = Statistics_data[Statistics_data['种植季次']=='第一季']
first_season_price = {}
for _, row in first_season_data.iterrows():
    if row['作物编号'] in first_season_price:
        if row['平均单价'] != first_season_price[row['作物编号']-16]:
            raise ValueError(f"作物编号 {row['作物编号']} 对应的平均单价不一致")
    else:
        # 如果作物编号不在字典中，则添加到字典中
        first_season_price[row['作物编号']-16] = row['平均单价']

first_season_price[0]=7
first_season_price
second_season_price={}
second_season_data = Statistics_data[Statistics_data['种植季次']=='第二季']
for _, row in second_season_data.iterrows():
    price_key = row['作物编号'] - 16
    if second_season_price.get(price_key) is not None:
        if row['平均单价'] != second_season_price[price_key]:
            raise ValueError(f"作物编号 {row['作物编号']} 对应的平均单价不一致")
    else:
        # 如果作物编号不在字典中，则添加到字典中
        second_season_price[price_key] = row['平均单价']
second_season_price[0]=0
array_size = 26
first_season= np.zeros((array_size))
for key, value in first_season_price.items():
    if key <= array_size:  # 确保索引在数组范围内
        first_season[key ] = value  # 键-1作为索引
second_season= np.zeros((array_size))
for key, value in second_season_price.items():
    if key <= array_size:  # 确保索引在数组范围内
        second_season[key ] = value  # 键-1作为索引

# sc
# sc[0]=first_season
sc=second_season
sc.shape
# Out:
# C:\Users\34999\AppData\Local\Temp\ipykernel_46596\1498386854.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   plant_data['种植地块'] = plant_data['种植地块'].fillna(method='ffill')
# (26,)

# %%
b=market[market['地块类型']=='平旱地'][['种植成本/(元/亩)']]
s=market[market['地块类型']=='平旱地'][[ '种植成本/(元/亩)']]
Exp=pd.read_excel(r"D:\adocument\数学建模\24年国赛\CUMCM2024Problems\exp.xlsx")
Exp=Exp.drop(columns=['作物编号'])
# sc=pd.read_excel(r"D:\adocument\数学建模\24年国赛\CUMCM2024Problems\s.xlsx")
bean_class_indices=crop_class['是否豆类'].iloc
bean_class_indices = [i for i, value in enumerate(bean_class_indices[15:]) if value == 1]

# bc=b['种植成本/(元/亩)']
# sc=sc['平均单价'].iloc[:15]
# pro.iloc[0,0]

# area=one_area['地块面积/亩'].iloc[:]
Exp=[Exp.iloc[i+15,0] for i in range(41-15)]
len(Exp)
# Out:
# 26

# %%
# import cvxpy as cp

# x={t:cp.Variable((26,15)) for t in range(nt)}
# S=cp.Variable(7)
# B=cp.Variable(7) 
# s=cp.Constant(sc.iloc[:,1])
# p=cp.Constant(pro.iloc[0:,1:])
# # dl=cp.Constant(crop_class['是否豆类'].iloc[:15])
# exp=cp.Constant(Exp.iloc[:15])
# area=cp.Constant(one_area['地块面积/亩'].iloc[:])
# theta = cp.Constant(0.5)
# for t in range(nt): 
#     sum_x_p = cp.sum(cp.multiply(x[t], p), axis=0) # 计算 x_{ijt} * p_{ij} 的总和
#     # 计算 min 和 max 部分
#     min_expr = cp.minimum(sum_x_p, exp)  # min{sum_x_p, exp_j}
#     max_expr = cp.maximum(sum_x_p - exp, 0)  # max{sum_x_p - exp_j, 0}
#     B[t]=cp.sum(x[t][:,:]*b[None,:])
#     S[t]=cp.sum(cp.sum(s*min_expr)+theta*cp.sum(s*max_expr))
# obejective=cp.Maximize(cp.sum(S)-cp.sum(B))
# # 定义二进制变量 z_{tij}
# z = {t: cp.Variable((ni, nj), boolean=True) for t in range(nt)}
# # 定义常数 M
# M = 1000  # 选择一个足够大的常数
# # 添加约束条件 x_{ti j} * x_{(t-1)i j} = 0
# constraints = []
# for t in range(1, nt):
#     for i in range(ni):
#         for j in range(nj):
#             # x_{ti j} * x_{(t-1)i j} <= M * z_{t-1ij}
#             constraints.append(x[t][i, j] <= M * z[t][i, j])
#             constraints.append(x[t-1][i, j] <= M * z[t][i, j])
#             constraints.append(x[t][i, j] + x[t-1][i, j] <= M * (1 - z[t][i, j]))
# for t in range(nt):
#     for i in range(ni):
#         # 添加约束 ∑_{j=0}^{n_j} x_{tij} ≤ crea_i
#         constraints.append(cp.sum(x[t][i, :]) <= area[i])
# for t in range(2, nt):
#     for i in range(ni):
#         # 对于豆类作物的索引 j
#         bean_sum = cp.sum([x[t-1][i, j] for j in bean_class_indices])  # ∑_{j \in 豆类} x_{(t-1)i j}
#         constraints.append(bean_sum + x_dict[t-1][i, j] + x_dict[t-2][i, j] >= area[i])

# constraints.append(x >= 0)

# # 构建优化问题
# problem = cp.Problem(objective, constraints)
# problem.solve()
# print(f"Optimal x:\n{x.value}")
bean_class_indices
# Out:
# [1, 2, 3]

# %%
from ortools.linear_solver import pywraplp
ni=24
nj=41-15
nt=7
solver = pywraplp.Solver.CreateSolver('SCIP')
# solver.SetSolverSpecificParametersAsString('log_level=2')  # 2 代表详细日志级别
y = [[[solver.IntVar(0, 1, f'y_{t}_{i}_{j}') for j in range(nj)] for i in range(ni)] for t in range(nt)]
x = [[[solver.NumVar(0, 40, f'x_{t}_{i}_{j}') for j in range(nj)] for i in range(ni)] for t in range(nt)]

theta=0
# b = [solver.NumVar(0, solver.infinity(), f'b_{j}') for j in range(nj)]
B = [solver.NumVar(0, solver.infinity(), f'B_{t}') for t in range(nt)]
S = [solver.NumVar(0, solver.infinity(), f'S_{t}') for t in range(nt)]
for t in range(nt):
    B[t] = solver.Sum(bc.iloc[i,j] * x[t][i][j] for i in range(ni) for j in range(nj))
output =[[solver.NumVar(0, solver.infinity(), f'output_{t}_{j}') for j in range(nj)] for t in range(nt)]
remain =[[solver.NumVar(0, solver.infinity(), f'remain_{t}_{j}') for j in range(nj)] for t in range(nt)]
for t in range(nt):
    sum_output = solver.Sum([sc[j] * output[t][j] for j in range(nj)])
    sum_remain = theta*solver.Sum([sc[j] * remain[t][j] for j in range(nj)])
    for j in range(nj):
        # 约束2: output_{t}_{j} <= sum_{i=1} x_{ijt} * pro_{ij}
        sum_pro = solver.Sum(x[t][i][j] * pro.iloc[i,j] for i in range(ni))
        solver.Add(output[t][j] <= sum_pro)
        # 约束3: output_{t}_{j} <= exp_{j}
        solver.Add(output[t][j] <= Exp[j])
        # 约束4: remain_{t}_{j} >= 0
        solver.Add(remain[t][j] >= 0)
        # 约束5: remain_{t}_{j} >= sum_{i=1} x_{ijt} * pro_{ij} - exp_{j}
        solver.Add(remain[t][j] >= sum_pro - Exp[j])
    S[t]=sum_output+sum_remain

for i in range(ni):
    for t in range(nt):
        constraint_expr = solver.Sum(x[t][i][j] for j in range(nj))
        solver.Add(constraint_expr <= area[t][i])

# for t in range(nt): 
#     if t==0:
#         for i in range(ni):
#             for j in range(nj):
#                 solver.Add(y[t][i][j] + y0.iloc[i,j] <= 1)
#     else:
#         for i in range(ni):
#             for j in range(nj):
#                 solver.Add(y[t][i][j] + y[t -1][i][j] <= 1)
big_M = 10000
for t in range(nt):
    for i in range(ni):
        for j in range(nj):
            solver.Add(x[t][i][j] <= big_M * y[t][i][j])
# for i in range(ni):
#     for t in range(1,nt):
#         if(t==1): 
#             # 创建约束
#             constraint_expr = solver.Sum(x[t][i][j] + x[t-1][i][j] + x0.iloc[i,j] for j in bean_class_indices)
#             solver.Add(constraint_expr >= area[t][i])
#         else:
#             # 创建约束
#             constraint_expr = solver.Sum(x[t][i][j] + x[t-1][i][j] + x[t-2][i][j] for j in bean_class_indices)
#             solver.Add(constraint_expr >= area[t][i])
N = 5
for j in range(nj):
    for t in range(nt):
        # 创建约束
        constraint_expr = solver.Sum(y[t][i][j] for i in range(ni))
        solver.Add(constraint_expr <= N)
M = 0.4

for t in range(nt):
    for j in range(nj):
        for i in range(ni):
            # 创建约束
            constraint_expr = x[t][i][j] >= M * y[t][i][j] * area[t][i]
            solver.Add(constraint_expr)
solver.SetTimeLimit(120000)
solver.EnableOutput()
objective_expr = solver.Sum(S[t] for t in range(nt)) - solver.Sum(B[t] for t in range(nt))
solver.Maximize(objective_expr)
status = solver.Solve()
status
# Out:
# 0

# %%
# 输出结果
import numpy as np
if status == pywraplp.Solver.OPTIMAL:
    print('Optimal solution found.')
    print('Solution:')
    for t in range(nt):
        print(S[t].solution_value()-B[t].solution_value())
        # print(f'S_{t} = {S[t].solution_value()}')
        # print(f'B_{t} = {B[t].solution_value()}')
    x_np = np.array([[[x[t][i][j].solution_value() for j in range(nj)] for i in range(ni)] for t in range(nt)])
    x_np[x_np < 0.001] = 0
    y_np = np.array([[[y[t][i][j].solution_value() for j in range(nj)] for i in range(ni)] for t in range(nt)])
    # x_df = pd.DataFrame(x_np[2], columns=[f'j_{j}' for j in range(nj)], index=[f'i_{i}' for i in range(ni)])
    # y_df = pd.DataFrame(y_np[1], columns=[f'j_{j}' for j in range(nj)], index=[f'i_{i}' for i in range(ni)])
elif status == pywraplp.Solver.INFEASIBLE:
    print('Problem is infeasible.')
elif status == pywraplp.Solver.UNBOUNDED:
    print('Problem is unbounded.')
elif status == pywraplp.Solver.ABNORMAL:
    print('Solver encountered an abnormal termination.')
else:
    print('Solver status unknown.')
    print(status)
    for t in range(nt):
        # print(f'S_{t}-B_{t} = {S[t].solution_value()-B[t].solution_value()}')
        # print(f'B_{t} = {B[t].solution_value()}')
        print(f'S_{t}-B_{t} = {S[t].solution_value()-B[t].solution_value()}')
    print('x values:')
    x_np = np.array([[[x[t][i][j].solution_value() for j in range(nj)] for i in range(ni)] for t in range(nt)])
    x_np[x_np < 0.001] = 0
    y_np = np.array([[[y[t][i][j].solution_value() for j in range(nj)] for i in range(ni)] for t in range(nt)])
    # x_df = pd.DataFrame(x_np[2], columns=[f'j_{j}' for j in range(nj)], index=[f'i_{i}' for i in range(ni)])
    # y_df = pd.DataFrame(y_np[1], columns=[f'j_{j}' for j in range(nj)], index=[f'i_{i}' for i in range(ni)])
file_path = r'D:\adocument\数学建模\24年国赛\CUMCM2024Problems\x3.xlsx'
with pd.ExcelWriter(file_path, engine='xlsxwriter') as writer:
    for i in range(nt):
        x_df = pd.DataFrame(x_np[i], columns=[f'j_{j}' for j in range(nj)], index=[f'i_{i}' for i in range(ni)])
        x_df.to_excel(writer, sheet_name=str(2024 + i))
# Out:
# Optimal solution found.
# Solution:
# 1848800.0
# 1848800.0
# 1848800.0
# 1848800.0
# 1848800.0
# 1848800.0
# 1848800.0
